# %% [markdown]
# <a href="https://colab.research.google.com/github/gsahithi017-cmd/Data-Science/blob/main/titanic_dispersion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94455067-1399-4a5d-9744-e2a5a0c49726" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94455067-1399-4a5d-9744-e2a5a0c49726">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("titanic.csv")

print("First Five Records")
print(df.head())
# Out:
# First Five Records
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
print("\nDataset Shape:", df.shape)
# Out:
# Dataset Shape: (891, 12)

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])

print("\nNumerical Columns")
print(numeric_df.columns)
# Out:
# Numerical Columns
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
print("\nRange")
print(numeric_df.max() - numeric_df.min())

print("\nVariance")
print(numeric_df.var())

print("\nStandard Deviation")
print(numeric_df.std())

print("\nInterquartile Range (IQR)")
Q1 = numeric_df.quantile(0.25)
Q3 = numeric_df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Range
# PassengerId    890.0000
# Survived         1.0000
# Pclass           2.0000
# Age             79.5800
# SibSp            8.0000
# Parch            6.0000
# Fare           512.3292
# dtype: float64
#
# Variance
# PassengerId    66231.000000
# Survived           0.236772
# Pclass             0.699015
# Age              211.019125
# SibSp              1.216043
# Parch              0.649728
# Fare            2469.436846
# dtype: float64
#
# Standard Deviation
# PassengerId    257.353842
# Survived         0.486592
# Pclass           0.836071
# Age             14.526497
# SibSp            1.102743
# Parch            0.806057
# Fare            49.693429
# dtype: float64
#
# Interquartile Range (IQR)
# PassengerId    445.0000
# Survived         1.0000
# Pclass           1.0000
# Age             17.8750
# SibSp            1.0000
# Parch            0.0000
# Fare            23.0896
# dtype: float64

# %%
numeric_df.hist(figsize=(12,10))
plt.suptitle("Histograms of Numerical Features")
plt.show()

# %%
numeric_df.boxplot(figsize=(12,6))
plt.title("Boxplot of Numerical Features")
plt.xticks(rotation=45)
plt.show()

# %%
numeric_df['Age'].plot(kind='density')
plt.title("Density Plot of Age")
plt.xlabel("Age")
plt.show()

# %%
plt.scatter(df['Age'], df['Fare'])
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()
